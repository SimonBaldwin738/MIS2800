# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonBaldwin738/MIS2800/blob/main/IC3_WK3_Baldwin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('SuperBowl_Finance.db')
print("SuperBowl_Finance database created")
# Out:
# SuperBowl_Finance database created

# %%
# %sql sqlite:///SuperBowl_Finance.db

# %% [markdown]
# # exercises

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS stock_performance(
#   ticker TEXT,
# price_before_game REAL,
# price_week_after_game REAL,
# trading_volume_millions INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# INSERT INTO stock_performance (ticker, price_before_game, price_week_after_game, trading_volume_millions)
# VALUES
# ('PEP',168.50,172.10,45),
# ('GOOGL',142.80,145.20,110),
# ('AMZN',170.20,178.45,95),
# ('VZ',40.10,39.85, 60),
# ('TSLA',190.00,185.20,150),
# ('TMUS',197.68,199.34,100),
# ('STLA',22.40,23.10,15);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# -- Creating another table named Ad_Buys
# CREATE TABLE Ad_Buys (
# ticker TEXT PRIMARY KEY,
# company_name TEXT,
# ad_cost_millions REAL
# );
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# INSERT INTO ad_buys (ticker, company_name, ad_cost_millions)
# VALUES
# ('PEP', 'PepsiCo', 7.0),
# ('GOOGL', 'Alphabet (Google)', 14.0),
# ('AMZN', 'Amazon', 14.0),
# ('VZ', 'Verizon', 7.0),
# ('TSLA', 'Tesla', 0.0), -- Tesla doesn't buy ads
# ('TMUS', 'Tmobile', 10.0),
# ('STLA', 'Stellantis (Jeep)', 6.5);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM stock_performance;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15)]

# %%
# %%sql
# select ticker, price_before_game from  stock_performance order by ticker asc
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('AMZN', 170.2),
#  ('GOOGL', 142.8),
#  ('PEP', 168.5),
#  ('STLA', 22.4),
#  ('TMUS', 197.68),
#  ('TSLA', 190.0),
#  ('VZ', 40.1)]

# %%
# %%sql
# select * from stock_performance where ticker like 'T%'
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 190.0, 185.2, 150), ('TMUS', 197.68, 199.34, 100)]

# %%
# %%sql
# select price_week_after_game from stock_performance where price_week_after_game > 150
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [(172.1,), (178.45,), (185.2,), (199.34,)]

# %%
# %%sql
# SELECT * FROM ad_buys
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 'PepsiCo', 7.0),
#  ('GOOGL', 'Alphabet (Google)', 14.0),
#  ('AMZN', 'Amazon', 14.0),
#  ('VZ', 'Verizon', 7.0),
#  ('TSLA', 'Tesla', 0.0),
#  ('TMUS', 'Tmobile', 10.0),
#  ('STLA', 'Stellantis (Jeep)', 6.5)]

# %%
# %%sql
# select ticker, company_name from ad_buys order by "company name" DESC
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 'PepsiCo'),
#  ('GOOGL', 'Alphabet (Google)'),
#  ('AMZN', 'Amazon'),
#  ('VZ', 'Verizon'),
#  ('TSLA', 'Tesla'),
#  ('TMUS', 'Tmobile'),
#  ('STLA', 'Stellantis (Jeep)')]

# %%
# %%sql
# SELECT ticker from ad_buys where ticker like 'T%'
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TMUS',), ('TSLA',)]
